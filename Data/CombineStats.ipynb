# %%
import pandas as pd

# %%
combine = pd.read_excel('/Users/caleboneel/Downloads/combinestatistics.xlsx')

# %%
combine
# Out:
#                 Player  Pos                School        College    Ht   Wt  \
# 0      Johnathan Abram    S     Mississippi State  College Stats  71.0  205
# 1           Paul Adams   OT              Missouri  College Stats  78.0  317
# 2       Nasir Adderley    S              Delaware            NaN  72.0  206
# 3      Azeez Al-Shaair   LB      Florida Atlantic  College Stats  73.0  234
# 4          Otaro Alaka   LB             Texas A&M  College Stats  75.0  239
# ...                ...  ...                   ...            ...   ...  ...
# 3356     Jason Worilds  OLB         Virginia Tech  College Stats  73.0  254
# 3357  Doug Worthington   DT            Ohio State  College Stats  77.0  292
# 3358      Major Wright    S               Florida  College Stats  71.0  206
# 3359         Sam Young   OT            Notre Dame            NaN  80.0  316
# 3360      Willie Young   DE  North Carolina State  College Stats  77.0  251
#
#       40yd Vertical Bench Broad Jump 3Cone Shuttle  \
# ...

# %%
comb = combine[['Player', 'Pos', 'Ht', 'Wt', '40yd', 'Vertical', 'Bench', 'Broad Jump', '3Cone', 'Shuttle']]

# %%
comb['Player'] = comb["Player"].str.lower()
comb
# Out:
# <ipython-input-10-018685640a74>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comb['Player'] = comb["Player"].str.lower()
#                 Player  Pos    Ht   Wt  40yd Vertical Bench Broad Jump 3Cone  \
# 0      johnathan abram    S  71.0  205  4.45      NaN   NaN        116   NaN
# 1           paul adams   OT  78.0  317  5.18       27    16        103  7.68
# 2       nasir adderley    S  72.0  206   NaN      NaN   NaN        NaN   NaN
# 3      azeez al-shaair   LB  73.0  234   NaN      NaN    16        NaN   NaN
# 4          otaro alaka   LB  75.0  239  4.82       36    20        131   NaN
# ...                ...  ...   ...  ...   ...      ...   ...        ...   ...
# ...

# %%
players = pd.read_csv('/Users/caleboneel/Desktop/final-project-coneel/Data/filtereddf.csv')

# %%
players.drop(columns=['_merge'], inplace = True)

# %%
totaldf = players.merge(comb, how = 'left', left_on = 'Name', right_on = 'Player', indicator = True)

# %%
totaldf['_merge'].value_counts()
# Out:
# both          1499
# left_only      213
# right_only       0
# Name: _merge, dtype: int64
